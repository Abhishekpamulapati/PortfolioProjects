# %% [markdown]
# This project is to explore the datasets on laptops to understand better these space, and time complexities of an algorithm. And preprocessing the data can significantly speed up the an algorithm.

# %% [markdown]
# So to better understand those concepts, we imagine the laptop and explore the dataset.

# %%
import csv

with open('laptop_price.csv') as f:
    reader = csv.reader(f)
    rows = list(reader)
    header = rows[0]
    rows = rows[1:]
    
print(header)
for i in range(5):
    print(rows[i])
# Out:
# ['laptop_ID', 'Company', 'Product', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price_euros']
# ['1', 'Apple', 'MacBook Pro', 'Ultrabook', '13.3', 'IPS Panel Retina Display 2560x1600', 'Intel Core i5 2.3GHz', '8GB', '128GB SSD', 'Intel Iris Plus Graphics 640', 'macOS', '1.37kg', '1339.69']
# ['2', 'Apple', 'Macbook Air', 'Ultrabook', '13.3', '1440x900', 'Intel Core i5 1.8GHz', '8GB', '128GB Flash Storage', 'Intel HD Graphics 6000', 'macOS', '1.34kg', '898.94']
# ['3', 'HP', '250 G6', 'Notebook', '15.6', 'Full HD 1920x1080', 'Intel Core i5 7200U 2.5GHz', '8GB', '256GB SSD', 'Intel HD Graphics 620', 'No OS', '1.86kg', '575.00']
# ['4', 'Apple', 'MacBook Pro', 'Ultrabook', '15.4', 'IPS Panel Retina Display 2880x1800', 'Intel Core i7 2.7GHz', '16GB', '512GB SSD', 'AMD Radeon Pro 455', 'macOS', '1.83kg', '2537.45']
# ...

# %% [markdown]
# Inventory Class :- to verify the schema and look at the same data in the dataset

# %%
class inventory():
    def __init__(self, csv_filename):
        with open(csv_filename) as f:
            reader = csv.reader(f)
            rows = list(reader)
        self.header = rows[0]
        self.rows = rows[1:]
        for row in self.rows:
            row[-1] = float(row[-1])
            
inventory = inventory('laptop_price.csv')
print(inventory.header)
print(len(inventory.rows))
# Out:
# ['laptop_ID', 'Company', 'Product', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price_euros']
# 1303

# %%
class inventory():

    
    def __init__(self, csv_filename):
        with open(csv_filename) as f:
            reader = csv.reader(f)
            rows = list(reader)
        self.header = rows[0]
        self.rows = rows[1:]
        for row in self.rows:
            row[-1] = float(row[-1])
        self.id_to_row = {}
        for row in self.rows:
            self.id_to_row[row[0]] = row
    
    def get_laptop_from_id_fast(self, laptop_ID):   # step 1
        return self.id_to_row.get(laptop_ID, None)   # step 2
            
    def get_laptop_from_id(self, laptop_ID):   # step 1
        for row in self.rows:                  # step 2
            if row[0] == laptop_ID:
                return row
        return None

# %% [markdown]
# Finding the Laptop ID from the inventory dataset

# %%
inventory = inventory('laptop_price.csv')
print(inventory.get_laptop_from_id('37')) 
print(inventory.get_laptop_from_id('3362736'))
# Out:
# ['37', 'Acer', 'Aspire 3', 'Notebook', '15.6', '1366x768', 'Intel Core i3 7130U 2.7GHz', '4GB', '1TB HDD', 'Intel HD Graphics 620', 'Linux', '2.1kg', 367.0]
# None

# %%
class inventory():

    
    def __init__(self, csv_filename):
        with open(csv_filename) as f:
            reader = csv.reader(f)
            rows = list(reader)
        self.header = rows[0]
        self.rows = rows[1:]
        for row in self.rows:
            row[-1] = float(row[-1])
            
    def get_laptop_from_id(self, laptop_ID):   # step 1
        for row in self.rows:                  # step 2
            if row[0] == laptop_ID:
                return row
        return None    
inventory = inventory('laptops.csv')
print(inventory.get_laptop_from_id('3362737')) 
print(inventory.get_laptop_from_id('3362736'))
# Out:
# ['3362737', 'HP', '250 G6', 'Notebook', '15.6', 'Full HD 1920x1080', 'Intel Core i5 7200U 2.5GHz', '8GB', '256GB SSD', 'Intel HD Graphics 620', 'No OS', '1.86kg', 575.0]
# None

# %%
class Inventory():                    
    
    def __init__(self, csv_filename):
        with open(csv_filename) as f: 
            reader = csv.reader(f)
            rows = list(reader)
        self.header = rows[0]        
        self.rows = rows[1:]
        for row in self.rows:              
            row[-1] = int(row[-1])
        self.id_to_row = {}                         # step 1
        for row in self.rows:                       # step 2
            self.id_to_row[row[0]] = row 
    
    def get_laptop_from_id(self, laptop_id):
        for row in self.rows:                 
            if row[0] == laptop_id:
                return row
        return None   
    
    def get_laptop_from_id_fast(self, laptop_id):   # step 3
        if laptop_id in self.id_to_row:             # step 4
            return self.id_to_row[laptop_id]
        return None

# %%
inventory = Inventory('laptops.csv')                # step 5
print(inventory.get_laptop_from_id_fast('3362737')) # step 6
print(inventory.get_laptop_from_id_fast('3362736')) # step 7
# Out:
# ['3362737', 'HP', '250 G6', 'Notebook', '15.6', 'Full HD 1920x1080', 'Intel Core i5 7200U 2.5GHz', '8GB', '256GB SSD', 'Intel HD Graphics 620', 'No OS', '1.86kg', 575]
# None

# %% [markdown]
# Comparing the performances of both the functions

# %%
import time                                                         
import random                                                       

ids = [str(random.randint(1000000, 9999999)) for _ in range(10000)] 
inventory = Inventory('laptops.csv')                               

total_time_no_dict = 0                                              
for identifier in ids:                                              
    start = time.time()                                            
    inventory.get_laptop_from_id(identifier)                        
    end = time.time()                                               
    total_time_no_dict += end - start                               
    
total_time_dict = 0                                                 
for identifier in ids:                                              
    start = time.time()                                             
    inventory.get_laptop_from_id_fast(identifier)                  
    end = time.time()                                              
    total_time_dict += end - start                                  
    
print(total_time_no_dict)                                           
print(total_time_dict)
# Out:
# 0.3582000732421875
# 0.0027441978454589844

# %% [markdown]
# Checking the promotion of the laptops in dollars -function to check whether we can spend a given amount by purchasing either 1 or 2 laptops

# %%
class Inventory():                    
    
    def __init__(self, csv_filename):
        with open(csv_filename) as f: 
            reader = csv.reader(f)
            rows = list(reader)
        self.header = rows[0]        
        self.rows = rows[1:]
        for row in self.rows:              
            row[-1] = int(row[-1])
        self.id_to_row = {}                         
        for row in self.rows:                       
            self.id_to_row[row[0]] = row 
    
    def get_laptop_from_id(self, laptop_id):
        for row in self.rows:                 
            if row[0] == laptop_id:
                return row
        return None   
    
    def get_laptop_from_id_fast(self, laptop_id):   
        if laptop_id in self.id_to_row:             
            return self.id_to_row[laptop_id]
        return None


    def check_promotion_dollars(self,dollars):
        for row in self.rows:
            if row[-1] == dollars:
                return True
        for row1 in self.rows:
            for row2 in self.rows:
                if row1[-1]+row2[-1] == dollars:
                    return True
        return False

# %%
inventory = Inventory('laptops.csv')
print(inventory.check_promotion_dollars(1000))
print(inventory.check_promotion_dollars(442))
# Out:
# True
# False

# %% [markdown]
# Optimizing the laptop promotion - creating a fast version of the function

# %%
class Inventory():                    
    
    def __init__(self, csv_filename):
        with open(csv_filename) as f: 
            reader = csv.reader(f)
            rows = list(reader)
        self.header = rows[0]        
        self.rows = rows[1:]
        for row in self.rows:              
            row[-1] = int(row[-1])
        self.id_to_row = {}                         
        for row in self.rows:                       
            self.id_to_row[row[0]] = row 

        self.price = set()
        for row in self.rows:
            self.price.add(row[-1])

    
    def get_laptop_from_id(self, laptop_id):
        for row in self.rows:                 
            if row[0] == laptop_id:
                return row
        return None   
    
    def get_laptop_from_id_fast(self, laptop_id):   
        if laptop_id in self.id_to_row:             
            return self.id_to_row[laptop_id]
        return None


    def check_promotion_dollars(self,dollars):
        for row in self.rows:
            if row[-1] == dollars:
                return True
        for row1 in self.rows:
            for row2 in self.rows:
                if row1[-1]+row2[-1] == dollars:
                    return True
        return False
    
    def check_promotion_dollars_fast(self,dollars):
        if dollars in self.price:
            return True
        for price in self.price:
            if dollars - price in self.price:
                return True
        return False

# %%
inventory = Inventory('laptops.csv')
print(inventory.check_promotion_dollars_fast(1000))
print(inventory.check_promotion_dollars_fast(442))
# Out:
# True
# False

# %% [markdown]
# Comparing the performance of both the functions of promotion

# %%
prices = [random.randint(100,5000) for _ in range(100)]

inventory = Inventory('laptops.csv')

total_time_no_set = 0 
for price in prices:
    start = time.time()
    inventory.check_promotion_dollars(price)
    end = time.time()
    total_time_no_set += end - start 

total_time_set = 0
for price in prices:
    start = time.time()
    inventory.check_promotion_dollars_fast(price)
    end = time.time()
    total_time_set += end - start

print(total_time_no_set)
print(total_time_set)
# Out:
# 0.3829050064086914
# 0.0

# %% [markdown]
# Analysis - we are 38 percent faster with set() in the function

# %%
class Inventory():                    
    
    def __init__(self, csv_filename):
        with open(csv_filename) as f: 
            reader = csv.reader(f)
            rows = list(reader)
        self.header = rows[0]        
        self.rows = rows[1:]
        for row in self.rows:              
            row[-1] = int(row[-1])
        self.id_to_row = {}                         
        for row in self.rows:                      
            self.id_to_row[row[0]] = row 
        
        self.prices = set()
        for row in self.rows:
            self.prices.add(row[-1])

        self.rows_by_price = sorted(self.rows, key=lambda row: row[-1])

    
    def get_laptop_from_id(self, laptop_id):
        for row in self.rows:                 
            if row[0] == laptop_id:
                return row
        return None   
    
    def get_laptop_from_id_fast(self, laptop_id):   
        if laptop_id in self.id_to_row:             
            return self.id_to_row[laptop_id]
        return None


    def check_promotion_dollars(self,dollars):
        for row in self.rows:
            if row[-1] ==dollars:
                True
        for row1 in self.rows:
            for row2 in self.rows:
                if row1[-1]+row2[-1] == dollars:
                    True
        return False


    def check_promotion_dollars_fast(self,dollars):
        if dollars in self.prices:
            return True
        for price in self.prices:
            if dollars - price in self.prices:
                return True

        return False

    def find_first_laptop_more_expensive(self, target_price):
        range_start = 0
        range_end = len(self.rows_by_price) - 1
        result_index = -1

        while range_start <= range_end:
            mid = (range_start + range_end) // 2
            price = self.rows_by_price[mid][-1]

            if price > target_price:
                result_index = mid
                range_end = mid - 1
            else:
                range_start = mid + 1

        return result_index

# %%
inventory = Inventory('laptops.csv')
print(inventory.find_first_laptop_more_expensive(1000))
print(inventory.find_first_laptop_more_expensive(10000))
# Out:
# 683
# -1
