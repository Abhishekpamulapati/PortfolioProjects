# %% [markdown]
# ####Answer the below questions on sf_fire_calls table

# %%
fire_df = spark.read.table("dev.spark_db.sf_fire_calls")

# %% [markdown]
# ##### Q1. How many distinct types of calls were made to the Fire Department?
# ``` sql
#     select count(distinct CallType) as distinct_call_type_count
#     from dev.spark_db.sf_fire_calls
# ```

# %%
# %sql
select count(distinct CallType) as distinct_call_type_count
    from dev.spark_db.sf_fire_calls
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>distinct_call_type_count</th></tr></thead><tbody><tr><td>30</td></tr></tbody></table></div>

# %%
ans1_df = (fire_df.selectExpr("count(distinct CallType) as distinct_call_type_count")
           
)
ans1_df.show()
# Out:
# +------------------------+
# |distinct_call_type_count|
# +------------------------+
# |                      30|
# +------------------------+

# %% [markdown]
# ##### Q2. What were distinct types of calls made to the Fire Department?
# ```sql
#   select distinct CallType as distinct_call_types
#   from dev.spark_db.sf_fire_calls
#   where CallType is not null
# ```

# %%
# %sql
  select distinct CallType as distinct_call_types
  from dev.spark_db.sf_fire_calls
  where CallType is not null
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>distinct_call_types</th></tr></thead><tbody><tr><td>Structure Fire</td></tr><tr><td>Medical Incident</td></tr><tr><td>Vehicle Fire</td></tr><tr><td>Alarms</td></tr><tr><td>Odor (Strange / Unknown)</td></tr><tr><td>Smoke Investigation (Outside)</td></tr><tr><td>Other</td></tr><tr><td>Outside Fire</td></tr><tr><td>Citizen Assist / Service Call</td></tr><tr><td>Electrical Hazard</td></tr><tr><td>Elevator / Escalator Rescue</td></tr><tr><td>Water Rescue</td></tr><tr><td>Gas Leak (Natural and LP Gases)</td></tr><tr><td>Aircraft Emergency</td></tr><tr><td>Industrial Accidents</td></tr><tr><td>Fuel Spill</td></tr><tr><td>Suspicious Package</td></tr><tr><td>Oil Spill</td></tr><tr><td>HazMat</td></tr><tr><td>Train / Rail Incident</td></tr><tr><td>Traffic Collision</td></tr><tr><td>Explosion</td></tr><tr><td>High Angle Rescue</td></tr><tr><td>Assist Police</td></tr><tr><td>Extrication / Entrapped (Machinery, Vehicle)</td></tr><tr><td>Mutual Aid / Assist Outside Agency</td></tr><tr><td>Marine Fire</td></tr><tr><td>Administrative</td></tr><tr><td>Watercraft in Distress</td></tr><tr><td>Confined Space / Structure Collapse</td></tr></tbody></table></div>

# %%
ans2_df = ( fire_df.where("CallType is not null")
           .selectExpr("CallType as distinct_call_types")
           .distinct()
           )
ans2_df.show()
# Out:
# +--------------------+
# | distinct_call_types|
# +--------------------+
# |      Structure Fire|
# |    Medical Incident|
# |        Vehicle Fire|
# |              Alarms|
# |Odor (Strange / U...|
# |Smoke Investigati...|
# |               Other|
# |        Outside Fire|
# |Citizen Assist / ...|
# |   Electrical Hazard|
# |Elevator / Escala...|
# |        Water Rescue|
# |Gas Leak (Natural...|
# |  Aircraft Emergency|
# |Industrial Accidents|
# |          Fuel Spill|
# |  Suspicious Package|
# |           Oil Spill|
# |              HazMat|
# |Train / Rail Inci...|
# +--------------------+
# only showing top 20 rows

# %% [markdown]
# ##### Q3. Find out all response for delayed times greater than 5 mins?
# ``` sql
#   select CallNumber, Delay
#   from dev.spark_db.sf_fire_calls
#   where Delay > 5
# ```

# %%
ans3_df = (fire_df.where("Delay > 5")
                  .select("CallNumber", "Delay")   
)
ans3_df.show()
# Out:
# +----------+---------+
# |CallNumber|    Delay|
# +----------+---------+
# |  20110315|     5.35|
# |  20120147|     6.25|
# |  20130013|      5.2|
# |  20140067|      5.6|
# |  20140177|     7.25|
# |  20150056|11.916667|
# |  20150254| 5.116667|
# |  20150265| 8.633333|
# |  20150265| 95.28333|
# |  20150380|     5.45|
# |  20150414|      7.6|
# |  20160059| 6.133333|
# |  20160064|5.1833334|
# |  20170118|6.9166665|
# |  20170342|      5.2|
# |  20180129|     6.35|
# |  20180191| 7.983333|
# |  20180382|    13.55|
# |  20190062|     5.15|
# |  20190097|13.583333|
# +----------+---------+
# only showing top 20 rows

# %% [markdown]
# ##### Q4. What were the most common call types?
# ```sql
#   select CallType, count(*) as count
#   from dev.spark_db.sf_fire_calls
#   where CallType is not null
#   group by CallType
#   order by count desc
# ```

# %%
(fire_df.select("CallType")
    .where("CallType is not null")
    .groupBy("CallType")
    .count()
    .orderBy("count", ascending=False)
    .show()
)
# Out:
# +--------------------+------+
# |            CallType| count|
# +--------------------+------+
# |    Medical Incident|113794|
# |      Structure Fire| 23319|
# |              Alarms| 19406|
# |   Traffic Collision|  7013|
# |Citizen Assist / ...|  2524|
# |               Other|  2166|
# |        Outside Fire|  2094|
# |        Vehicle Fire|   854|
# |Gas Leak (Natural...|   764|
# |        Water Rescue|   755|
# |Odor (Strange / U...|   490|
# |   Electrical Hazard|   482|
# |Elevator / Escala...|   453|
# |Smoke Investigati...|   391|
# |          Fuel Spill|   193|
# |              HazMat|   124|
# |Industrial Accidents|    94|
# |           Explosion|    89|
# |Train / Rail Inci...|    57|
# |  Aircraft Emergency|    36|
# +--------------------+------+
# only showing top 20 rows

# %% [markdown]
# ##### Q5. What zip codes accounted for most common calls?
# ```sql
#   select CallType, ZipCode, count(*) as count
#   from dev.spark_db.sf_fire_calls
#   where CallType is not null
#   group by CallType, Zipcode
#   order by count desc
# ```

# %%
(fire_df.select("CallType", "ZipCode")
    .where("CallType is not null")
    .groupBy("CallType", "Zipcode")
    .count()
    .orderBy("count", ascending=False)
    .show()
)
# Out:
# +----------------+-------+-----+
# |        CallType|Zipcode|count|
# +----------------+-------+-----+
# |Medical Incident|  94102|16130|
# |Medical Incident|  94103|14775|
# |Medical Incident|  94110| 9995|
# |Medical Incident|  94109| 9479|
# |Medical Incident|  94124| 5885|
# |Medical Incident|  94112| 5630|
# |Medical Incident|  94115| 4785|
# |Medical Incident|  94122| 4323|
# |Medical Incident|  94107| 4284|
# |Medical Incident|  94133| 3977|
# |Medical Incident|  94117| 3522|
# |Medical Incident|  94134| 3437|
# |Medical Incident|  94114| 3225|
# |Medical Incident|  94118| 3104|
# |Medical Incident|  94121| 2953|
# |Medical Incident|  94116| 2738|
# |Medical Incident|  94132| 2594|
# |  Structure Fire|  94110| 2267|
# |Medical Incident|  94105| 2258|
# |  Structure Fire|  94102| 2229|
# +----------------+-------+-----+
# only showing top 20 rows

# %% [markdown]
# ##### Q6. What San Francisco neighborhoods are in the zip codes 94102 and 94103
# ```sql
#   select distinct Neighborhood, Zipcode
#   from dev.spark_db.sf_fire_calls
#   where Zipcode== 94102 or Zipcode == 94103
# ```

# %%
(fire_df.where("Zipcode== 94102 or Zipcode == 94103")
        .select("Neighborhood", "Zipcode")
        .distinct()
        .show()
)
# Out:
# +--------------------+-------+
# |        Neighborhood|Zipcode|
# +--------------------+-------+
# |          Tenderloin|  94102|
# |     South of Market|  94103|
# |             Mission|  94103|
# |        Hayes Valley|  94102|
# |Financial Distric...|  94103|
# |          Tenderloin|  94103|
# |     South of Market|  94102|
# |            Nob Hill|  94102|
# |Financial Distric...|  94102|
# |         Mission Bay|  94103|
# |    Western Addition|  94102|
# | Castro/Upper Market|  94103|
# |        Potrero Hill|  94103|
# |        Hayes Valley|  94103|
# +--------------------+-------+

# %% [markdown]
# ##### Q7. What was the sum of all calls, average, min and max of the response times for calls?
# ```sql
#   select sum(NumAlarms), avg(Delay), min(Delay), max(Delay)
#   from dev.spark_db.sf_fire_calls
# ```

# %%
(fire_df.selectExpr("sum(NumAlarms)", "avg(Delay)", "min(Delay)", "max(Delay)")
        .show()
)
# Out:
# +--------------+------------------+-----------+----------+
# |sum(NumAlarms)|        avg(Delay)| min(Delay)|max(Delay)|
# +--------------+------------------+-----------+----------+
# |        176170|3.8923641541750063|0.016666668|   1844.55|
# +--------------+------------------+-----------+----------+

# %% [markdown]
# ##### Q8. How many distinct years of data is in the CSV file?
# ```sql
#   select distinct year(CallDate) as year_num
#   from dev.spark_db.sf_fire_calls
#   order by year_num
# ```

# %%
(fire_df.selectExpr("year(CallDate) as year_num")
    .distinct()
    .orderBy("year_num")
    .show()
)
# Out:
# +--------+
# |year_num|
# +--------+
# |    2000|
# |    2001|
# |    2002|
# |    2003|
# |    2004|
# |    2005|
# |    2006|
# |    2007|
# |    2008|
# |    2009|
# |    2010|
# |    2011|
# |    2012|
# |    2013|
# |    2014|
# |    2015|
# |    2016|
# |    2017|
# |    2018|
# +--------+

# %% [markdown]
# ##### Q9. What week of the year in 2018 had the most fire calls?
# ```sql
#   select weekofyear(CallDate) as week_year, count(*) as count
#   from dev.spark_db.sf_fire_calls
#   where year(CallDate) == 2018
#   group by week_year
#   order by count desc
# ```

# %%
(fire_df.selectExpr("weekofyear(CallDate) as week_year")
    .where("year(CallDate) == 2018")
    .groupBy('week_year')
    .count()
    .orderBy('count', ascending=False)
    .show()
)
# Out:
# +---------+-----+
# |week_year|count|
# +---------+-----+
# |       22|  259|
# |       40|  255|
# |       43|  250|
# |       25|  249|
# |        1|  246|
# |       44|  244|
# |       32|  243|
# |       13|  243|
# |       11|  240|
# |        5|  236|
# |       18|  236|
# |       23|  235|
# |       42|  234|
# |        2|  234|
# |       31|  234|
# |       19|  233|
# |       10|  232|
# |       34|  232|
# |        8|  232|
# |       28|  231|
# +---------+-----+
# only showing top 20 rows

# %% [markdown]
# ##### Q10. What neighborhoods in San Francisco had the worst response time in 2018?
# ```sql
#   select Neighborhood, Delay
#   from dev.spark_db.sf_fire_calls
#   where year(CallDate) == 2018
# ```

# %%
(fire_df.select("Neighborhood", "Delay")
    .filter("year(CallDate) == 2018")    
    .show()
)
# Out:
# +--------------------+---------+
# |        Neighborhood|    Delay|
# +--------------------+---------+
# |    Presidio Heights|2.8833334|
# |         Mission Bay|6.3333335|
# |           Chinatown|     2.65|
# |Financial Distric...|3.5333333|
# |          Tenderloin|      1.1|
# |Bayview Hunters P...|     4.05|
# |      Inner Richmond|2.5666666|
# |        Inner Sunset|      1.4|
# |     Sunset/Parkside|2.6666667|
# |     South of Market|1.7666667|
# |    Golden Gate Park|1.6833333|
# |      Bernal Heights|     3.65|
# |          Tenderloin|      4.2|
# |         Mission Bay|6.3333335|
# |         Mission Bay|      6.6|
# |      Outer Richmond|3.4833333|
# |           Excelsior|0.8333333|
# |         North Beach|     2.55|
# |    Western Addition|2.1666667|
# |        Hayes Valley|3.1333334|
# +--------------------+---------+
# only showing top 20 rows
